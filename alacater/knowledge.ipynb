# %%
# %pip install crewai

from crewai import LLM, Agent, Crew, Process, Task
from crewai.knowledge.source.crew_docling_source import CrewDoclingSource
from crewai.knowledge.docling import DoclingDocument
# Create a knowledge source
content_source = CrewDoclingSource(
    file_paths=[
        "https://lilianweng.github.io/posts/2024-11-28-reward-hacking",
        "https://lilianweng.github.io/posts/2024-07-07-hallucination",
    ],
)

# Create an LLM with a temperature of 0 to ensure deterministic outputs
llm = LLM(model="gpt-4o-mini", temperature=0)

# Create an agent with the knowledge store
agent = Agent(
    role="About papers",
    goal="You know everything about the papers.",
    backstory="""You are a master at understanding papers and their content.""",
    verbose=True,
    allow_delegation=False,
    llm=llm,
)
task = Task(
    description="Answer the following questions about the papers: {question}",
    expected_output="An answer to the question.",
    agent=agent,
)

crew = Crew(
    agents=[agent],
    tasks=[task],
    verbose=True,
    process=Process.sequential,
    knowledge_sources=[
        content_source
    ],  # Enable knowledge by adding the sources here. You can also add more sources to the sources list.
)

result = crew.kickoff(
    inputs={
        "question": "What is the reward hacking paper about? Be sure to provide sources."
    }
)

result
# Out:
# Requirement already satisfied: crewai in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (0.95.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (4.7.2)
# Requirement already satisfied: blinker>=1.9.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.7.2)
# Requirement already satisfied: json-repair>=0.25.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (0.35.0)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm>=1.44.22 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.59.1)
# Requirement already satisfied: openai>=1.13.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.59.9)
# Requirement already satisfied: openpyxl>=3.1.5 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.29.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (0.11.5)
# Requirement already satisfied: pydantic>=2.4.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (2.10.5)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.0.1)
# Requirement already satisfied: pyvis>=0.3.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from crewai) (0.5.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.5 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (3.11.11)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.3.0)
# Requirement already satisfied: build>=1.0.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (2.2.2)
# Requirement already satisfied: posthog>=2.4.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (3.8.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (1.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.50b0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (1.69.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (3.1.5)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (2.27.2)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from litellm>=1.44.22->crewai) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from litellm>=1.44.22->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from litellm>=1.44.22->crewai) (0.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.29.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (5.29.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-sdk>=1.22.0->crewai) (0.50b0)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (8.31.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (4.0.1)
# Requirement already satisfied: networkx>=1.11 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.10)
# Requirement already satisfied: packaging>=19.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (24.2)
# Requirement already satisfied: pyproject_hooks in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.17.2)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.41.3)
# Requirement already satisfied: certifi in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb>=0.5.23->crewai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb>=0.5.23->crewai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.5.23->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai) (3.21.0)
# Requirement already satisfied: decorator in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.19.1)
# Requirement already satisfied: stack_data in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.9)
# Requirement already satisfied: coloredlogs in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (24.12.23)
# Requirement already satisfied: sympy in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.50b0)
# Requirement already satisfied: asgiref~=3.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai) (0.27.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (14.2)
# Requirement already satisfied: pycparser in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9)
# Requirement already satisfied: filelock in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.5.23->crewai) (2024.12.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/sachinmurali/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 get_ipython().run_line_magic('pip', 'install crewai')
#       3 from crewai import LLM, Agent, Crew, Process, Task
# ----> 4 from crewai.knowledge.source.crew_docling_source import CrewDoclingSource
#       5 from crewai.knowledge.docling import DoclingDocument
#       6 # Create a knowledge source
#
# File ~/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages/crewai/knowledge/source/crew_docling_source.py:22
#      18 from crewai.utilities.constants import KNOWLEDGE_DIRECTORY
#      19 from crewai.utilities.logger import Logger
# ---> 22 class CrewDoclingSource(BaseKnowledgeSource):
#      23     """Default Source class for converting documents to markdown or json
#      24     This will auto support PDF, DOCX, and TXT, XLSX, Images, and HTML files without any additional dependencies and follows the docling package as the source of truth.
#      25     """
#      27     def __init__(self, *args, **kwargs):
#
# File ~/Desktop/CrewAI-Agent/venv-crewai/lib/python3.12/site-packages/crewai/knowledge/source/crew_docling_source.py:41, in CrewDoclingSource()
#      39 chunks: List[str] = Field(default_factory=list)
#      40 safe_file_paths: List[Union[Path, str]] = Field(default_factory=list)
# ---> 41 content: List[DoclingDocument] = Field(default_factory=list)
#      42 document_converter: DocumentConverter = Field(
#      43     default_factory=lambda: DocumentConverter(
#      44         allowed_formats=[
#    (...)
#      54     )
#      55 )
#      57 def model_post_init(self, _) -> None:
#
# NameError: name 'DoclingDocument' is not defined
